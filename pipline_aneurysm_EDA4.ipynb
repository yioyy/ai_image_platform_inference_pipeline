# %%
import os
import time
import numpy as np
import pydicom
import glob
import shutil
import nibabel as nib
import matplotlib
import matplotlib.pyplot as plt
import sys
import logging
import cv2
import pandas as pd
import subprocess

# %%
# #load excel
# path_excel = '/data/4TB1/pipeline/chuan/excel/'

# excel_name = 'ClinicalTest.xlsx'
# #excel_name = 'AI_Normal.xlsx'

# #先讀取excel，取得patientid跟accession_number當成資料夾檔名條件
# dtypes1 = {'ID': str, 'PatientID': str, 'StudyDate': str, 'AccessionNumber': str, 'SubjectLabel': str, 'ExperimentLabel': str, 
#           'SeriesInstanceUID': str, 'url': str}

# df = pd.read_excel(os.path.join(path_excel, excel_name), dtype=dtypes1).fillna('')
# IDs = list(df['ID'])

# %%
IDs = sorted(os.listdir('/data/chuan/Deep_Aneurysm/data/Skull_fat_FalsePositive/Dicom_TMMH'))

# %%
#這邊是用舊的for迴圈方式
for idx, ID in enumerate(IDs):
    if idx >= 39:
        print([idx], ID, ' Start...')
        Inputs = os.path.join('/data/chuan/Deep_Aneurysm/data/Skull_fat_FalsePositive/Image_TMMH', ID + '_MRA_BRAIN.nii.gz')
        DicomDir = os.path.join('/data/chuan/Deep_Aneurysm/data/Skull_fat_FalsePositive/Dicom_TMMH', ID, 'MRA_BRAIN')
        Output_folder = os.path.join('/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/example_output', ID)
        gpu_n = '3'
        cmd = [
               "python", "pipeline_aneurysm_tensorflow.py",
               "--ID", ID,
               "--Inputs", Inputs,
               "--DicomDir", DicomDir,
               "--Output_folder", Output_folder,
               "--gpu_n", gpu_n,
              ]

        gpu_env = os.environ.copy()
        gpu_env["CUDA_VISIBLE_DEVICES"] = gpu_n
        subprocess.run(cmd, env=gpu_env)
# Out:
# [39] 78834683_20200911_MR_3090092659  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/78834683_20200911_MR_3090092659/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/78834683_20200911_MR_3090092659/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/78834683_20200911_MR_3090092659/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# old shape: (140, 1008, 1008), new_shape: [ 98 210 210], old_spacing: [0.699999988079071, 0.2083333283662796, 0.2083333283662796], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f8dccd916c0>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 43218
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [96, 256, 256]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 98, 256, 256])
# data_vessel pad後的大小: torch.Size([1, 98, 256, 256])
# n_steps 2, image size is torch.Size([98, 256, 256]), tile_size [96, 256, 256], tile_step_size 0.25
# steps:
# [[0, 2], [0], [0]]
# [Gaussian模式] 處理 2 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 1.26 sec
# before
# predicted_array_or_file.shape: (2, 98, 210, 210)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1008, 1008)
# current_spacing: [1.0, 1.0, 1.0]
# properties_dict[spacing]: [0.699999988079071, 0.2083333283662796, 0.2083333283662796]
# after
# predicted_array_or_file.shape: (2, 140, 1008, 1008)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.500018
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1008, 1008)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.500018
# [Done] spend 30.66 sec
# [Done Get brain mask... ] spend 54 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/78834683_20200911_MR_3090092659/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/78834683_20200911_MR_3090092659/Brain/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([64, 128, 128])
# old shape: (140, 1008, 1008), new_shape: [140 467 467], old_spacing: [0.699999988079071, 0.2083333283662796, 0.2083333283662796], new_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f8dccd916c0>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 72862
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [64, 128, 128]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 467, 467])
# data_vessel pad後的大小: torch.Size([1, 140, 467, 467])
# n_steps 864, image size is torch.Size([140, 467, 467]), tile_size [64, 128, 128], tile_step_size 0.25
# steps:
# [[0, 15, 30, 46, 61, 76], [0, 31, 62, 92, 123, 154, 185, 216, 247, 277, 308, 339], [0, 31, 62, 92, 123, 154, 185, 216, 247, 277, 308, 339]]
# [Gaussian模式] 處理 718 個���血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 16.78 sec
# before
# predicted_array_or_file.shape: (2, 140, 467, 467)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1008, 1008)
# current_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.2083333283662796, 0.2083333283662796]
# after
# predicted_array_or_file.shape: (2, 140, 1008, 1008)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1008, 1008)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 29.77 sec
# [Done Vessel AI Inference... ] spend 53 sec
# [Done Get vessel post-process... ] spend 13 sec
# >>> predict_vessel_16labels .......................>>> (1008, 1008, 140)
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/78834683_20200911_MR_3090092659/Normalized_Image/DeepAneurysm_00001_0000.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/78834683_20200911_MR_3090092659/Vessel.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/78834683_20200911_MR_3090092659/Vessel_16.nii.gz
# [Done Get vessel 16labels... ] spend 238 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/78834683_20200911_MR_3090092659/Normalized_Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/78834683_20200911_MR_3090092659/Vessel/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 0 cases.
# inference_gaussian.shape: torch.Size([16, 32, 32])
# [Done Aneurysm AI Inference... ] spend 8 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/78834683_20200911_MR_3090092659/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 52s 52s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 78834683_20200911_MR_3090092659  Start...
# Running stage 1: Aneurysm inference!!!
# [Done stage 1: Aneurysm AI Inference... ] spend 382 sec
# [Done SynthSEG AI Inference... ] spend 85 sec
# reslice OK!!!
# [Done reslice... ] spend 124 sec
# [Done decompress_JEPG... ] spend 20 sec
# np.max(pred): 4 <class 'numpy.int16'>
# 從 Image Position 計算的 slice spacing: 0.7000 mm
# MIP 序列將使用統一的 slice_thickness: 0.7000 mm
# img.shape: (1008, 1008, 470) translated_pred: torch.Size([466, 1008, 1008])
# [MIP 數值驗證] MIP_Pitch MIP_images dtype=int32, min=0, max=178629
# end!!!
