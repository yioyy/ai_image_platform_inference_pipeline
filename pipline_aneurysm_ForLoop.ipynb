# %%
import os
import time
import numpy as np
import pydicom
import glob
import shutil
import nibabel as nib
import matplotlib
import matplotlib.pyplot as plt
import sys
import logging
import cv2
import pandas as pd
import subprocess

# %%
#load excel
path_excel = '/data/4TB1/pipeline/chuan/excel/'

excel_name = 'ClinicalTest.xlsx'
#excel_name = 'AI_Normal.xlsx'

#先讀取excel，取得patientid跟accession_number當成資料夾檔名條件
dtypes1 = {'ID': str, 'PatientID': str, 'StudyDate': str, 'AccessionNumber': str, 'SubjectLabel': str, 'ExperimentLabel': str, 
          'SeriesInstanceUID': str, 'url': str}

df = pd.read_excel(os.path.join(path_excel, excel_name), dtype=dtypes1).fillna('')
IDs = list(df['ID'])

# %%
#這邊是用舊的for迴圈方式
for idx, ID in enumerate(IDs):
    print([idx], ID, ' Start...')
    Inputs = os.path.join('/data/4TB1/pipeline/chuan/example_input', ID, 'MRA_BRAIN.nii.gz')
    DicomDir = os.path.join('/data/4TB1/pipeline/chuan/example_inputDicom', ID, 'MRA_BRAIN')
    Output_folder = '/data/4TB1/pipeline/chuan/example_output/'
    cmd = [
           "python", "pipeline_aneurysm_tensorflow_test_ForLoop.py",
           "--ID", ID,
           "--Inputs", Inputs,
           "--DicomDir", DicomDir,
           "--Output_folder", Output_folder,
          ]

    subprocess.run(cmd)
# Out:
# [0] 00719692_20250522_MR_21405210094  Start...
# 2025-06-23 11:53:32.503475: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-23 11:53:32.503505: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-23 11:53:32.503512: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-23 11:53:32.507969: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-23 11:53:38.878241: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 11:53:38.882643: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 11:53:38.885938: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 11:53:38.890509: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 11:53:38.894366: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 11:53:38.898449: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [Done load AI model... ] spend 13 sec
# [Done SynthSEG... ] spend 31 sec
# BET target_spacing = [0.600001 0.600001 0.600001]
# pad value = 0.0
# Initializing...
# Parameters: bt=0.500000, d1=20.000000, d2=10.000000, rmin=3.330000, rmax=10.000000
# tmin: 0.000000, t2: 0.000000, t: 48.300000, t98: 483.000000, tmax: 2919.000000
# Center-of-Mass: [221.59373194 216.41727243 111.27590375]
# Head Radius: 136.157752
# Median within Head Radius: 291.000000
# Initializing surface...
# Brain extractor initialization complete!
# Running surface deformation...
# Iteration: 999
# Complete.
# >>> modify_brain_mask ...>>> (512, 512, 148)
# [Done BET... ] spend 95 sec
# >>> predict_vessel .....................>>> (512, 512, 148)
# [Done Get vessel mask... ] spend 29 sec
# [Done Get vessel skeleton... ] spend 38 sec
# >>> predict_vessel_16labels ....................>>> (512, 512, 148)
# [Done get vessel 16labels... ] spend 47 sec
# >>> predict_aneurysm ........................................................................................>>> (512, 512, 148)
# [Done Pred aneurysm... ] spend 171 sec
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/brain_mask.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/Vessel.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/Vessel_16.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/Pred.nii.gz
# /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/Prob.nii.gz
# [Done Save results... ] spend 7 sec
# 2025-06-23 12:01:20.760364: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:01:20.765010: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:01:20.768077: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:01:20.906796: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:01:20.907992: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:01:20.909076: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:01:20.910116: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22332 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:02:00.0, compute capability: 8.6
# Chris Rorden's dcm2niiX version v1.0.20240202  GCC12.3.0 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# DICOM images may be missing, expected 148 spatial locations per volume, but found 61 slices.
# Convert 61 DICOM as /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/Image_reslice/MIP_Pitchi (512x512x61x1)
# Conversion required 0.594826 seconds (0.540813 for core code).
# Chris Rorden's dcm2niiX version v1.0.20240202  GCC12.3.0 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# DICOM images may be missing, expected 148 spatial locations per volume, but found 61 slices.
# Convert 61 DICOM as /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00719692_20250522_MR_21405210094/Image_reslice/MIP_Yawg (512x512x61x1)
# Conversion required 0.501910 seconds (0.483436 for core code).
# WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3a670730): Non uniform sampling or missing slices detected,  maximum nonuniformity:0.000219776
#
# WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3a670730): Non uniform sampling or missing slices detected,  maximum nonuniformity:0.000219776
#
# WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f552390): Non uniform sampling or missing slices detected,  maximum nonuniformity:0.000219776
#
# WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3f552390): Non uniform sampling or missing slices detected,  maximum nonuniformity:0.000219776
#
# WARNING: In /tmp/SimpleITK-build/ITK-prefix/include/ITK-5.4/itkImageSeriesReader.hxx, line 478
# ImageSeriesReader (0x3b971190): Non uniform sampling or missing slices detected,  maximum nonuniformity:0.000219776
# 00719692_20250522_MR_21405210094  Start...
# Running stage 1: Aneurysm inference!!!
# [Done AI Inference... ] spend 437 sec
# reslice OK!!!
# [Done reslice... ] spend 23 sec
# img.shape: (512, 512, 197) translated_pred: torch.Size([195, 512, 512])
# [Done create_MIP_pred... ] spend 66 sec
# [0] 00719692_21405210094  Start...
# [0] 00719692_20250522_MR_21405210094  Start...
# [Done calculate_aneurysm_long_axis... ] spend 5 sec
# [0] 00719692_20250522_MR_21405210094  Start....
# Dicom-SEG ok!!!
# [Done create_dicomseg... ] spend 9 sec
# [0] 00719692_20250522_MR_21405210094  mask json start...
# AneurysmNumber: 4
# Processing complete!
# [Done make_pred_json... ] spend 4 sec
# [Done orthanc_zip_upload... ] spend 0 sec
# [Done start_upload_json... ] spend 0 sec
# [Done All Pipeline!!! ] spend 546 sec
# end!!!
# [1] 00921585_20250530_MR_21405290061  Start...
# 2025-06-23 12:02:46.675425: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-23 12:02:46.675455: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-23 12:02:46.675464: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-23 12:02:46.680165: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-23 12:02:51.213915: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:02:51.217143: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:02:51.220416: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:02:51.223568: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:02:51.225865: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:02:51.228769: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [Done load AI model... ] spend 5 sec
# [Done SynthSEG... ] spend 31 sec
# BET target_spacing = [0.6 0.6 0.6]
# pad value = 0.0
# Initializing...
# Parameters: bt=0.500000, d1=20.000000, d2=10.000000, rmin=3.330000, rmax=10.000000
# tmin: 0.000000, t2: 0.000000, t: 56.800000, t98: 568.000000, tmax: 2661.000000
# Center-of-Mass: [213.27521044 206.22181282 106.29791463]
# Head Radius: 124.870010
# Median within Head Radius: 390.000000
# Initializing surface...
# Brain extractor initialization complete!
# Running surface deformation...
# Iteration: 999
# Complete.
# >>> modify_brain_mask ...>>> (512, 512, 136)
# [Done BET... ] spend 95 sec
# >>> predict_vessel ..................>>> (512, 512, 136)
# [Done Get vessel mask... ] spend 27 sec
# [Done Get vessel skeleton... ] spend 35 sec
# >>> predict_vessel_16labels ...................>>> (512, 512, 136)
# [Done get vessel 16labels... ] spend 41 sec
# >>> predict_aneurysm ....................................................................................>>> (512, 512, 136)
# [Done Pred aneurysm... ] spend 168 sec
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/brain_mask.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/Vessel.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/Vessel_16.nii.gz
# [save] ---> /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/Pred.nii.gz
# /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/Prob.nii.gz
# [Done Save results... ] spend 6 sec
# 2025-06-23 12:10:08.347385: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:10:08.350811: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:10:08.353622: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:10:08.468136: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:10:08.469377: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:10:08.470576: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:10:08.471616: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22332 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:02:00.0, compute capability: 8.6
# Chris Rorden's dcm2niiX version v1.0.20240202  GCC12.3.0 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# DICOM images may be missing, expected 136 spatial locations per volume, but found 61 slices.
# Convert 61 DICOM as /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/Image_reslice/MIP_Pitchc (512x512x61x1)
# Conversion required 0.591219 seconds (0.563927 for core code).
# Chris Rorden's dcm2niiX version v1.0.20240202  GCC12.3.0 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# DICOM images may be missing, expected 136 spatial locations per volume, but found 61 slices.
# Convert 61 DICOM as /data/4TB1/pipeline/chuan/process/Deep_Aneurysm/00921585_20250530_MR_21405290061/Image_reslice/MIP_Yawc (512x512x61x1)
# Conversion required 0.542254 seconds (0.504981 for core code).
# 00921585_20250530_MR_21405290061  Start...
# Running stage 1: Aneurysm inference!!!
# [Done AI Inference... ] spend 414 sec
# reslice OK!!!
# [Done reslice... ] spend 22 sec
# img.shape: (512, 512, 189) translated_pred: torch.Size([187, 512, 512])
# [Done create_MIP_pred... ] spend 54 sec
# [0] 00921585_21405290061  Start...
# [0] 00921585_20250530_MR_21405290061  Start...
# [Done calculate_aneurysm_long_axis... ] spend 2 sec
# [0] 00921585_20250530_MR_21405290061  Start....
# Dicom-SEG ok!!!
# [Done create_dicomseg... ] spend 0 sec
# [0] 00921585_20250530_MR_21405290061  mask json start...
# Processing complete!
# [Done make_pred_json... ] spend 2 sec
# [Done orthanc_zip_upload... ] spend 0 sec
# [Done start_upload_json... ] spend 0 sec
# [Done All Pipeline!!! ] spend 494 sec
# end!!!
# [2] 00926164_20250603_MR_21405290024  Start...
# 2025-06-23 12:11:07.596262: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-06-23 12:11:07.596291: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-06-23 12:11:07.596297: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-23 12:11:07.600761: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-06-23 12:11:12.079389: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:11:12.082383: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:11:12.085978: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:11:12.088899: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:11:12.091154: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2025-06-23 12:11:12.094075: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:894] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# [Done load AI model... ] spend 5 sec
# [Done SynthSEG... ] spend 31 sec
# BET target_spacing = [0.7 0.7 0.7]
# pad value = 0.0
# Initializing...
# Parameters: bt=0.500000, d1=20.000000, d2=10.000000, rmin=3.330000, rmax=10.000000
# tmin: 0.000000, t2: 0.000000, t: 46.600000, t98: 466.000000, tmax: 2241.000000
# Center-of-Mass: [202.79125253 188.23136736 106.14117326]
# Head Radius: 121.994101
# Median within Head Radius: 303.000000
# Initializing surface...
# Brain extractor initialization complete!
# Running surface deformation...
# Iteration: 999
# Complete.
# >>> modify_brain_mask ...>>> (512, 512, 144)
# [Done BET... ] spend 82 sec
# >>> predict_vessel ..................>>> (512, 512, 144)
# [Done Get vessel mask... ] spend 25 sec
# [Done Get vessel skeleton... ] spend 39 sec
# >>> predict_vessel_16labels ..................>>> (512, 512, 144)
# [Done get vessel 16labels... ] spend 41 sec
# >>> predict_aneurysm .............................................
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#       6 Output_folder = '/data/4TB1/pipeline/chuan/example_output/'
#       7 cmd = [
#       8        "python", "pipeline_aneurysm_tensorflow_test_ForLoop.py",
#       9        "--ID", ID,
#    (...)
#      12        "--Output_folder", Output_folder,
#      13       ]
# ---> 15 subprocess.run(cmd)
#
# File ~/miniconda3/envs/tf_2_14/lib/python3.10/subprocess.py:505, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
# --> 505         stdout, stderr = process.communicate(input, timeout=timeout)
#     506     except TimeoutExpired as exc:
#     507         process.kill()
#
# File ~/miniconda3/envs/tf_2_14/lib/python3.10/subprocess.py:1146, in Popen.communicate(self, input, timeout)
#    1144         stderr = self.stderr.read()
#    1145         self.stderr.close()
# -> 1146     self.wait()
#    1147 else:
#    1148     if timeout is not None:
#
# File ~/miniconda3/envs/tf_2_14/lib/python3.10/subprocess.py:1209, in Popen.wait(self, timeout)
#    1207     endtime = _time() + timeout
#    1208 try:
# -> 1209     return self._wait(timeout=timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # The first keyboard interrupt waits briefly for the child to
#    1213     # exit under the common assumption that it also received the ^C
#    1214     # generated SIGINT and will exit rapidly.
#    1215     if timeout is not None:
#
# File ~/miniconda3/envs/tf_2_14/lib/python3.10/subprocess.py:1959, in Popen._wait(self, timeout)
#    1957 if self.returncode is not None:
#    1958     break  # Another thread waited.
# -> 1959 (pid, sts) = self._try_wait(0)
#    1960 # Check the pid and loop as waitpid has been known to
#    1961 # return 0 even without WNOHANG in odd situations.
#    1962 # http://bugs.python.org/issue14396.
#    1963 if pid == self.pid:
#
# File ~/miniconda3/envs/tf_2_14/lib/python3.10/subprocess.py:1917, in Popen._try_wait(self, wait_flags)
#    1915 """All callers to this function MUST hold self._waitpid_lock."""
#    1916 try:
# -> 1917     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1918 except ChildProcessError:
#    1919     # This happens if SIGCLD is set to be ignored or waiting
#    1920     # for child processes has otherwise been disabled for our
#    1921     # process.  This child is dead, we can't get the status.
#    1922     pid = self.pid
#
# KeyboardInterrupt:
