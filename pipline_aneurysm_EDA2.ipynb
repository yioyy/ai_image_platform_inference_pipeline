# %%
import os
import time
import numpy as np
import pydicom
import glob
import shutil
import nibabel as nib
import matplotlib
import matplotlib.pyplot as plt
import sys
import logging
import cv2
import pandas as pd
import subprocess

# %%
# #load excel
# path_excel = '/data/4TB1/pipeline/chuan/excel/'

# excel_name = 'ClinicalTest.xlsx'
# #excel_name = 'AI_Normal.xlsx'

# #先讀取excel，取得patientid跟accession_number當成資料夾檔名條件
# dtypes1 = {'ID': str, 'PatientID': str, 'StudyDate': str, 'AccessionNumber': str, 'SubjectLabel': str, 'ExperimentLabel': str, 
#           'SeriesInstanceUID': str, 'url': str}

# df = pd.read_excel(os.path.join(path_excel, excel_name), dtype=dtypes1).fillna('')
# IDs = list(df['ID'])

# %%
IDs = sorted(os.listdir('/data/chuan/Deep_Aneurysm/data/Skull_fat_FalsePositive/Dicom_TMMH'))

# %%
#這邊是用舊的for迴圈方式
for idx, ID in enumerate(IDs):
    if idx >= 10 and idx < 20:
        print([idx], ID, ' Start...')
        Inputs = os.path.join('/data/chuan/Deep_Aneurysm/data/Skull_fat_FalsePositive/Image_TMMH', ID + '_MRA_BRAIN.nii.gz')
        DicomDir = os.path.join('/data/chuan/Deep_Aneurysm/data/Skull_fat_FalsePositive/Dicom_TMMH', ID, 'MRA_BRAIN')
        Output_folder = os.path.join('/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/example_output', ID)
        gpu_n = '1'
        cmd = [
               "python", "pipeline_aneurysm_tensorflow.py",
               "--ID", ID,
               "--Inputs", Inputs,
               "--DicomDir", DicomDir,
               "--Output_folder", Output_folder,
               "--gpu_n", gpu_n,
              ]

        gpu_env = os.environ.copy()
        gpu_env["CUDA_VISIBLE_DEVICES"] = gpu_n
        subprocess.run(cmd, env=gpu_env)
# Out:
# [10] 74976296_20140416_MR_3030030482  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/74976296_20140416_MR_3030030482/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/74976296_20140416_MR_3030030482/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/74976296_20140416_MR_3030030482/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# old shape: (140, 1024, 1024), new_shape: [ 98 220 220], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7ff32f14d630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 47432
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [96, 256, 256]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 98, 256, 256])
# data_vessel pad後的大小: torch.Size([1, 98, 256, 256])
# n_steps 2, image size is torch.Size([98, 256, 256]), tile_size [96, 256, 256], tile_step_size 0.25
# steps:
# [[0, 2], [0], [0]]
# [Gaussian模式] 處理 2 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 1.09 sec
# before
# predicted_array_or_file.shape: (2, 98, 220, 220)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [1.0, 1.0, 1.0]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.49999097
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.49999097
# [Done] spend 33.29 sec
# [Done Get brain mask... ] spend 57 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/74976296_20140416_MR_3030030482/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/74976296_20140416_MR_3030030482/Brain/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([64, 128, 128])
# old shape: (140, 1024, 1024), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7ff32f14d630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 70084
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [64, 128, 128]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 1014, image size is torch.Size([140, 490, 490]), tile_size [64, 128, 128], tile_step_size 0.25
# steps:
# [[0, 15, 30, 46, 61, 76], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362]]
# [Gaussian模式] 處理 786 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 18.23 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 33.35 sec
# [Done Vessel AI Inference... ] spend 62 sec
# [Done Get vessel post-process... ] spend 19 sec
# >>> predict_vessel_16labels ...................>>> (1024, 1024, 140)
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/74976296_20140416_MR_3030030482/Normalized_Image/DeepAneurysm_00001_0000.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/74976296_20140416_MR_3030030482/Vessel.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/74976296_20140416_MR_3030030482/Vessel_16.nii.gz
# [Done Get vessel 16labels... ] spend 225 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/74976296_20140416_MR_3030030482/Normalized_Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/74976296_20140416_MR_3030030482/Vessel/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([16, 32, 32])
# old shape: (140, 1024, 1024), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7ff32f14d630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 10000
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [16, 32, 32]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 111392, image size is torch.Size([140, 490, 490]), tile_size [16, 32, 32], tile_step_size 0.25
# steps:
# [[0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96, 100, 104, 108, 112, 116, 120, 124], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458]]
# [Gaussian模式] 處理 5727 個有血管的 patches，使用 batch_size=112
# Prediction done, transferring to CPU if needed
# [Done] spend 18.15 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 33.27 sec
# [Done Aneurysm AI Inference... ] spend 63 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/74976296_20140416_MR_3030030482/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 50s 50s/step
# 1/1 [==============================] - 1s 824ms/step
# 1/1 [==============================] - 2s 2s/step
# [11] 75322690_20230908_MR_3120096638  Start...
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x4eb810d0): /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75322690_20230908_MR_3120096638/Image/DeepAneurysm_00001_0000.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x4eb810d0): /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75322690_20230908_MR_3120096638/Image/DeepAneurysm_00001_0000.nii.gz has unexpected scales in sform
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75322690_20230908_MR_3120096638/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75322690_20230908_MR_3120096638/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75322690_20230908_MR_3120096638/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x1ad55df0): /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75322690_20230908_MR_3120096638/nnUNet/Image_nii/MRA_BRAIN.nii.gz has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x1ad55df0): /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75322690_20230908_MR_3120096638/nnUNet/Image_nii/MRA_BRAIN.nii.gz has unexpected scales in sform
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75322690_20230908_MR_3120096638/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 51s 51s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 2s 2s/step
# 75322690_20230908_MR_3120096638  Start...
# Running stage 1: Aneurysm inference!!!
# [Done stage 1: Aneurysm AI Inference... ] spend 67 sec
# [Done SynthSEG AI Inference... ] spend 156 sec
# end!!!
# [12] 75744136_20240528_MR_3130057908  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# old shape: (130, 560, 512), new_shape: [ 91 220 201], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fae01acd750>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 40241
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [96, 256, 256]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 96, 256, 256])
# data_vessel pad後的大小: torch.Size([1, 96, 256, 256])
# n_steps 1, image size is torch.Size([96, 256, 256]), tile_size [96, 256, 256], tile_step_size 0.25
# steps:
# [[0], [0], [0]]
# [Gaussian模式] 處理 1 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 0.93 sec
# before
# predicted_array_or_file.shape: (2, 91, 220, 201)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0061950684
# properties_dict[shape_after_cropping_and_before_resampling]: (130, 560, 512)
# current_spacing: [1.0, 1.0, 1.0]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 130, 560, 512)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.013878629
# revert cropping
# probs_reverted_cropping.shape: (2, 130, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 2.5438685e-06
# [Done] spend 6.36 sec
# [Done Get brain mask... ] spend 21 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/Brain/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([64, 128, 128])
# old shape: (130, 560, 512), new_shape: [130 490 448], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fae01acd750>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 72069
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [64, 128, 128]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 130, 490, 448])
# data_vessel pad後的大小: torch.Size([1, 130, 490, 448])
# n_steps 858, image size is torch.Size([130, 490, 448]), tile_size [64, 128, 128], tile_step_size 0.25
# steps:
# [[0, 13, 26, 40, 53, 66], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362], [0, 32, 64, 96, 128, 160, 192, 224, 256, 288, 320]]
# [Gaussian模式] 處理 668 ���有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 15.50 sec
# before
# predicted_array_or_file.shape: (2, 130, 490, 448)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (130, 560, 512)
# current_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 130, 560, 512)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 130, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 21.39 sec
# [Done Vessel AI Inference... ] spend 48 sec
# [Done Get vessel post-process... ] spend 4 sec
# >>> predict_vessel_16labels ....................>>> (560, 560, 130)
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/Normalized_Image/DeepAneurysm_00001_0000.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/Vessel.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/Vessel_16.nii.gz
# [Done Get vessel 16labels... ] spend 63 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/Normalized_Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/Vessel/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([16, 32, 32])
# old shape: (130, 560, 560), new_shape: [130 490 490], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fae01acd750>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 10000
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [16, 32, 32]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 130, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 130, 490, 490])
# n_steps 104430, image size is torch.Size([130, 490, 490]), tile_size [16, 32, 32], tile_step_size 0.25
# steps:
# [[0, 4, 8, 12, 16, 20, 24, 28, 31, 35, 39, 43, 47, 51, 55, 59, 63, 67, 71, 75, 79, 83, 86, 90, 94, 98, 102, 106, 110, 114], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458]]
# [Gaussian模式] 處理 6808 個有血管的 patches，使用 batch_size=112
# Prediction done, transferring to CPU if needed
# [Done] spend 17.87 sec
# before
# predicted_array_or_file.shape: (2, 130, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (130, 560, 560)
# current_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 130, 560, 560)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 130, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 24.67 sec
# [Done Aneurysm AI Inference... ] spend 49 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 50s 50s/step
# 1/1 [==============================] - 1s 777ms/step
# 1/1 [==============================] - 2s 2s/step
# Chris Rorden's dcm2niiX version v1.0.20250505  GCC10.2.1 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# 1 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# DICOM images may be missing, expected 130 spatial locations per volume, but found 60 slices.
# Warning: Unable to distinguish Philips fieldmaps: phase difference, two phase/magnitude, direct fieldmapping.Philips Scaling Values RS:RI:SS = 11.4393:0:0.000551498 (see PMC3998685)
# Convert 60 DICOM as /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Image_reslice/MIP_Pitch (560x560x60x1)
# Conversion required 1.450730 seconds (1.450048 for core code).
# Chris Rorden's dcm2niiX version v1.0.20250505  GCC10.2.1 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# 1 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# DICOM images may be missing, expected 130 spatial locations per volume, but found 60 slices.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Interslice distance varies in this volume (incompatible with NIfTI format).
# Warning: Unable to distinguish Philips fieldmaps: phase difference, two phase/magnitude, direct fieldmapping.Philips Scaling Values RS:RI:SS = 11.4393:0:0.000551498 (see PMC3998685)
# Convert 60 DICOM as /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Image_reslice/MIP_Yaw (560x560x60x1)
# Warning: Unable to rotate 3D volume: slices not equidistant: 0.700001 != 1.40001
# Only able to make equidistant slices from 8,16,24-bit integer or 32-bit float image data.75744136_20240528_MR_3130057908  Start...
# Running stage 1: Aneurysm inference!!!
# [Done stage 1: Aneurysm AI Inference... ] spend 198 sec
# [Done SynthSEG AI Inference... ] spend 86 sec
# reslice OK!!!
# [Done reslice... ] spend 27 sec
# [Done decompress_JEPG... ] spend 16 sec
# np.max(pred): 4 <class 'numpy.int16'>
# 從 Image Position 計算的 slice spacing: 0.7000 mm
# MIP 序列將使用統一的 slice_thickness: 0.7000 mm
# img.shape: (560, 560, 231) translated_pred: torch.Size([229, 560, 560])
# [MIP 數值驗證] MIP_Pitch MIP_images dtype=int32, min=0, max=428813
# Transfer syntax: 1.2.840.10008.1.2.1
# Image shape: (560, 560) dtype: uint16
# [MIP 數值驗證] MIP_Yaw MIP_images dtype=int32, min=0, max=428813
# Transfer syntax: 1.2.840.10008.1.2.1
# Image shape: (560, 560) dtype: uint16
# [Done create_MIP_pred... ] spend 85 sec
# Start: make_aneurysm_vessel_location_16labels_pred()
# Done: make_aneurysm_vessel_location_16labels_pred()
# Start: calculate_aneurysm_long_axis_make_pred()
# Done: calculate_aneurysm_long_axis_make_pred()
# Start: make_table_row_patient_pred()
# [0] 75744136_3130057908 Start...
# Done: make_table_row_patient_pred()
# Start: make_table_add_location()
# [0] 75744136_20240528_MR_3130057908 Start...
# Done: make_table_add_location()
# [Done calculate_aneurysm_long_axis... ] spend 5 sec
# Processing complete!an/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Dicom/Dicom-Seg/MIP_Yaw_A4.dcmcm
# [Done make_pred_json... ] spend 14 sec
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Dicom_zip/MRA_BRAIN 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Dicom_zip/MRA_BRAIN.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Dicom_zip/MIP_Pitch 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Dicom_zip/MIP_Pitch.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Dicom_zip/MIP_Yaw 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Dicom_zip/MIP_Yaw.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Dicom_zip/Dicom-Seg 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/Dicom_zip/Dicom-Seg.zip
# 200
#
# 200
#
# 200
#
# 200
#
# OK!!!
# [Done start_upload_dicom... ] spend 104 sec
# [Done All Pipeline!!! ] spend 390 sec
# [FollowUp] Skip: input_json is empty.
# [Upload] original json failed: /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75744136_20240528_MR_3130057908/nnUNet/JSON/75744136_20240528_MR_3130057908_platform_json.json err=[Errno 111] Connection refused
# end!!!
# [13] 75780569_20190325_MR_3080029609  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# old shape: (140, 560, 560), new_shape: [ 98 220 220], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f4625edd750>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 47432
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [96, 256, 256]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 98, 256, 256])
# data_vessel pad後的大小: torch.Size([1, 98, 256, 256])
# n_steps 2, image size is torch.Size([98, 256, 256]), tile_size [96, 256, 256], tile_step_size 0.25
# steps:
# [[0, 2], [0], [0]]
# [Gaussian模式] 處理 2 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 0.83 sec
# before
# predicted_array_or_file.shape: (2, 98, 220, 220)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 560, 560)
# current_spacing: [1.0, 1.0, 1.0]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 140, 560, 560)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5000038
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.5000038
# [Done] spend 7.29 sec
# [Done Get brain mask... ] spend 21 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/Brain/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([64, 128, 128])
# old shape: (140, 560, 560), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f4625edd750>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 73076
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [64, 128, 128]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 1014, image size is torch.Size([140, 490, 490]), tile_size [64, 128, 128], tile_step_size 0.25
# steps:
# [[0, 15, 30, 46, 61, 76], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362]]
# [Gaussian模式] 處理 701 ��有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 16.60 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 560, 560)
# current_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 140, 560, 560)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 23.21 sec
# [Done Vessel AI Inference... ] spend 51 sec
# [Done Get vessel post-process... ] spend 4 sec
# >>> predict_vessel_16labels ...................>>> (560, 560, 140)
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/Normalized_Image/DeepAneurysm_00001_0000.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/Vessel.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/Vessel_16.nii.gz
# [Done Get vessel 16labels... ] spend 66 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/Normalized_Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/Vessel/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([16, 32, 32])
# old shape: (140, 560, 560), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f4625edd750>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 10000
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [16, 32, 32]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 111392, image size is torch.Size([140, 490, 490]), tile_size [16, 32, 32], tile_step_size 0.25
# steps:
# [[0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96, 100, 104, 108, 112, 116, 120, 124], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458]]
# [Gaussian模式] 處理 9058 個有血管的 patches，使用 batch_size=112
# Prediction done, transferring to CPU if needed
# [Done] spend 18.53 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 560, 560)
# current_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 140, 560, 560)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 25.36 sec
# [Done Aneurysm AI Inference... ] spend 50 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 50s 50s/step
# 1/1 [==============================] - 1s 769ms/step
# 1/1 [==============================] - 2s 2s/step
# Chris Rorden's dcm2niiX version v1.0.20250505  GCC10.2.1 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# 1 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# DICOM images may be missing, expected 140 spatial locations per volume, but found 60 slices.
# Warning: Unable to distinguish Philips fieldmaps: phase difference, two phase/magnitude, direct fieldmapping.Philips Scaling Values RS:RI:SS = 8.21661:0:0.000961098 (see PMC3998685)
# Convert 60 DICOM as /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Image_reslice/MIP_Pitch (560x560x60x1)
# Conversion required 1.594002 seconds (1.593465 for core code).
# Chris Rorden's dcm2niiX version v1.0.20250505  GCC10.2.1 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# 1 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# DICOM images may be missing, expected 140 spatial locations per volume, but found 60 slices.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Interslice distance varies in this volume (incompatible with NIfTI format).
# Warning: Unable to distinguish Philips fieldmaps: phase difference, two phase/magnitude, direct fieldmapping.Philips Scaling Values RS:RI:SS = 8.21661:0:0.000961098 (see PMC3998685)
# Convert 60 DICOM as /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Image_reslice/MIP_Yaw (560x560x60x1)
# Warning: Unable to rotate 3D volume: slices not equidistant: 0.699999 != 1.4
# Only able to make equidistant slices from 8,16,24-bit integer or 32-bit float image data.75780569_20190325_MR_3080029609  Start...
# Running stage 1: Aneurysm inference!!!
# [Done stage 1: Aneurysm AI Inference... ] spend 208 sec
# [Done SynthSEG AI Inference... ] spend 84 sec
# reslice OK!!!
# [Done reslice... ] spend 24 sec
# [Done decompress_JEPG... ] spend 17 sec
# np.max(pred): 4 <class 'numpy.int16'>
# 從 Image Position 計算的 slice spacing: 0.7000 mm
# MIP 序列將使用統一的 slice_thickness: 0.7000 mm
# img.shape: (560, 560, 249) translated_pred: torch.Size([246, 560, 560])
# [MIP 數值驗證] MIP_Pitch MIP_images dtype=int32, min=0, max=334863
# Transfer syntax: 1.2.840.10008.1.2.1
# Image shape: (560, 560) dtype: uint16
# [MIP 數值驗證] MIP_Yaw MIP_images dtype=int32, min=0, max=334862
# Transfer syntax: 1.2.840.10008.1.2.1
# Image shape: (560, 560) dtype: uint16
# [Done create_MIP_pred... ] spend 85 sec
# Start: make_aneurysm_vessel_location_16labels_pred()
# Done: make_aneurysm_vessel_location_16labels_pred()
# Start: calculate_aneurysm_long_axis_make_pred()
# Done: calculate_aneurysm_long_axis_make_pred()
# Start: make_table_row_patient_pred()
# [0] 75780569_3080029609 Start...
# Done: make_table_row_patient_pred()
# Start: make_table_add_location()
# [0] 75780569_20190325_MR_3080029609 Start...
# Done: make_table_add_location()
# [Done calculate_aneurysm_long_axis... ] spend 6 sec
# Processing complete!an/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Dicom/Dicom-Seg/MIP_Yaw_A4.dcmcm
# [Done make_pred_json... ] spend 15 sec
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Dicom_zip/MRA_BRAIN 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Dicom_zip/MRA_BRAIN.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Dicom_zip/MIP_Pitch 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Dicom_zip/MIP_Pitch.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Dicom_zip/MIP_Yaw 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Dicom_zip/MIP_Yaw.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Dicom_zip/Dicom-Seg 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/Dicom_zip/Dicom-Seg.zip
# 200
#
# 200
#
# 200
#
# 200
#
# OK!!!
# [Done start_upload_dicom... ] spend 64 sec
# [Done All Pipeline!!! ] spend 352 sec
# [FollowUp] Skip: input_json is empty.
# [Upload] original json failed: /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/75780569_20190325_MR_3080029609/nnUNet/JSON/75780569_20190325_MR_3080029609_platform_json.json err=[Errno 111] Connection refused
# end!!!
# [14] 76082606_20200203_MR_3090011093  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76082606_20200203_MR_3090011093/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76082606_20200203_MR_3090011093/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76082606_20200203_MR_3090011093/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# old shape: (140, 560, 560), new_shape: [ 98 200 200], old_spacing: [0.699999988079071, 0.3571428656578064, 0.3571428656578064], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f3d2228d630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 39200
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [96, 256, 256]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 98, 256, 256])
# data_vessel pad後的大小: torch.Size([1, 98, 256, 256])
# n_steps 2, image size is torch.Size([98, 256, 256]), tile_size [96, 256, 256], tile_step_size 0.25
# steps:
# [[0, 2], [0], [0]]
# [Gaussian模式] 處理 2 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 1.04 sec
# before
# predicted_array_or_file.shape: (2, 98, 200, 200)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 560, 560)
# current_spacing: [1.0, 1.0, 1.0]
# properties_dict[spacing]: [0.699999988079071, 0.3571428656578064, 0.3571428656578064]
# after
# predicted_array_or_file.shape: (2, 140, 560, 560)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.4999949
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.4999949
# [Done] spend 10.44 sec
# [Done Get brain mask... ] spend 26 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76082606_20200203_MR_3090011093/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76082606_20200203_MR_3090011093/Brain/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([64, 128, 128])
# ...
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 1014, image size is torch.Size([140, 490, 490]), tile_size [64, 128, 128], tile_step_size 0.25
# steps:
# [[0, 15, 30, 46, 61, 76], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362]]
# [Gaussian模式] 處理 809 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 18.71 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 32.97 sec
# [Done Vessel AI Inference... ] spend 60 sec
# [Done Get vessel post-process... ] spend 20 sec
# >>> predict_vessel_16labels ....................>>> (1024, 1024, 140)
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76228759_20151124_MR_3040102399/Normalized_Image/DeepAneurysm_00001_0000.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76228759_20151124_MR_3040102399/Vessel.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76228759_20151124_MR_3040102399/Vessel_16.nii.gz
# [Done Get vessel 16labels... ] spend 297 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76228759_20151124_MR_3040102399/Normalized_Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76228759_20151124_MR_3040102399/Vessel/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([16, 32, 32])
# old shape: (140, 1024, 1024), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f488c689630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 10000
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [16, 32, 32]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 111392, image size is torch.Size([140, 490, 490]), tile_size [16, 32, 32], tile_step_size 0.25
# steps:
# [[0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96, 100, 104, 108, 112, 116, 120, 124], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458]]
# [Gaussian模式] 處理 8158 個有血管的 patches，使用 batch_size=112
# Prediction done, transferring to CPU if needed
# [Done] spend 18.10 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 32.63 sec
# [Done Aneurysm AI Inference... ] spend 62 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76228759_20151124_MR_3040102399/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 50s 50s/step
# 1/1 [==============================] - 1s 824ms/step
# 1/1 [==============================] - 2s 2s/step
# [19] 76370281_20190611_MR_3080060545  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76370281_20190611_MR_3080060545/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76370281_20190611_MR_3080060545/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76370281_20190611_MR_3080060545/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# old shape: (140, 1024, 1024), new_shape: [ 98 220 220], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f63c6489630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 47432
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [96, 256, 256]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 98, 256, 256])
# data_vessel pad後的大小: torch.Size([1, 98, 256, 256])
# n_steps 2, image size is torch.Size([98, 256, 256]), tile_size [96, 256, 256], tile_step_size 0.25
# steps:
# [[0, 2], [0], [0]]
# [Gaussian模式] 處理 2 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 1.53 sec
# before
# predicted_array_or_file.shape: (2, 98, 220, 220)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [1.0, 1.0, 1.0]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.50001335
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.50001335
# [Done] spend 35.10 sec
# [Done Get brain mask... ] spend 60 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76370281_20190611_MR_3080060545/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76370281_20190611_MR_3080060545/Brain/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([64, 128, 128])
# old shape: (140, 1024, 1024), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f63c6489630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 71011
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [64, 128, 128]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 1014, image size is torch.Size([140, 490, 490]), tile_size [64, 128, 128], tile_step_size 0.25
# steps:
# [[0, 15, 30, 46, 61, 76], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362]]
# [Gaussian模式] 處理 823 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 20.22 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 36.48 sec
# [Done Vessel AI Inference... ] spend 64 sec
# [Done Get vessel post-process... ] spend 21 sec
# >>> predict_vessel_16labels ...................>>> (1024, 1024, 140)
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76370281_20190611_MR_3080060545/Normalized_Image/DeepAneurysm_00001_0000.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76370281_20190611_MR_3080060545/Vessel.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76370281_20190611_MR_3080060545/Vessel_16.nii.gz
# [Done Get vessel 16labels... ] spend 229 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76370281_20190611_MR_3080060545/Normalized_Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76370281_20190611_MR_3080060545/Vessel/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([16, 32, 32])
# old shape: (140, 1024, 1024), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f63c6489630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 10000
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [16, 32, 32]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 111392, image size is torch.Size([140, 490, 490]), tile_size [16, 32, 32], tile_step_size 0.25
# steps:
# [[0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96, 100, 104, 108, 112, 116, 120, 124], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458]]
# [Gaussian模式] 處理 7186 個有血管的 patches，使用 batch_size=112
# Prediction done, transferring to CPU if needed
# [Done] spend 17.01 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 30.70 sec
# [Done Aneurysm AI Inference... ] spend 58 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76370281_20190611_MR_3080060545/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 51s 51s/step
# 1/1 [==============================] - 1s 787ms/step
# 1/1 [==============================] - 2s 2s/step
