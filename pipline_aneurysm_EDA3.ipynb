# %%
import os
import time
import numpy as np
import pydicom
import glob
import shutil
import nibabel as nib
import matplotlib
import matplotlib.pyplot as plt
import sys
import logging
import cv2
import pandas as pd
import subprocess

# %%
# #load excel
# path_excel = '/data/4TB1/pipeline/chuan/excel/'

# excel_name = 'ClinicalTest.xlsx'
# #excel_name = 'AI_Normal.xlsx'

# #先讀取excel，取得patientid跟accession_number當成資料夾檔名條件
# dtypes1 = {'ID': str, 'PatientID': str, 'StudyDate': str, 'AccessionNumber': str, 'SubjectLabel': str, 'ExperimentLabel': str, 
#           'SeriesInstanceUID': str, 'url': str}

# df = pd.read_excel(os.path.join(path_excel, excel_name), dtype=dtypes1).fillna('')
# IDs = list(df['ID'])

# %%
IDs = sorted(os.listdir('/data/chuan/Deep_Aneurysm/data/Skull_fat_FalsePositive/Dicom_TMMH'))

# %%
#這邊是用舊的for迴圈方式
for idx, ID in enumerate(IDs):
    if idx >= 20 and idx < 30:
        print([idx], ID, ' Start...')
        Inputs = os.path.join('/data/chuan/Deep_Aneurysm/data/Skull_fat_FalsePositive/Image_TMMH', ID + '_MRA_BRAIN.nii.gz')
        DicomDir = os.path.join('/data/chuan/Deep_Aneurysm/data/Skull_fat_FalsePositive/Dicom_TMMH', ID, 'MRA_BRAIN')
        Output_folder = os.path.join('/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/example_output', ID)
        gpu_n = '2'
        cmd = [
               "python", "pipeline_aneurysm_tensorflow.py",
               "--ID", ID,
               "--Inputs", Inputs,
               "--DicomDir", DicomDir,
               "--Output_folder", Output_folder,
               "--gpu_n", gpu_n,
              ]

        gpu_env = os.environ.copy()
        gpu_env["CUDA_VISIBLE_DEVICES"] = gpu_n
        subprocess.run(cmd, env=gpu_env)
# Out:
# [20] 76560791_20140924_MR_3030076660  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76560791_20140924_MR_3030076660/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76560791_20140924_MR_3030076660/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76560791_20140924_MR_3030076660/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# old shape: (140, 1024, 1024), new_shape: [ 98 220 220], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f7461e19630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 47432
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [96, 256, 256]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 98, 256, 256])
# data_vessel pad後的大小: torch.Size([1, 98, 256, 256])
# n_steps 2, image size is torch.Size([98, 256, 256]), tile_size [96, 256, 256], tile_step_size 0.25
# steps:
# [[0, 2], [0], [0]]
# [Gaussian模式] 處理 2 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 1.21 sec
# before
# predicted_array_or_file.shape: (2, 98, 220, 220)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [1.0, 1.0, 1.0]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5000018
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.5000018
# [Done] spend 33.62 sec
# [Done Get brain mask... ] spend 58 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76560791_20140924_MR_3030076660/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76560791_20140924_MR_3030076660/Brain/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([64, 128, 128])
# old shape: (140, 1024, 1024), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f7461e19630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 84147
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [64, 128, 128]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 1014, image size is torch.Size([140, 490, 490]), tile_size [64, 128, 128], tile_step_size 0.25
# steps:
# [[0, 15, 30, 46, 61, 76], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362]]
# [Gaussian模式] 處理 851 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 19.50 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 33.31 sec
# [Done Vessel AI Inference... ] spend 59 sec
# [Done Get vessel post-process... ] spend 19 sec
# >>> predict_vessel_16labels ....................>>> (1024, 1024, 140)
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76560791_20140924_MR_3030076660/Normalized_Image/DeepAneurysm_00001_0000.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76560791_20140924_MR_3030076660/Vessel.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76560791_20140924_MR_3030076660/Vessel_16.nii.gz
# [Done Get vessel 16labels... ] spend 227 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76560791_20140924_MR_3030076660/Normalized_Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76560791_20140924_MR_3030076660/Vessel/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([16, 32, 32])
# old shape: (140, 1024, 1024), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f7461e19630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 10000
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [16, 32, 32]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 111392, image size is torch.Size([140, 490, 490]), tile_size [16, 32, 32], tile_step_size 0.25
# steps:
# [[0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96, 100, 104, 108, 112, 116, 120, 124], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458]]
# [Gaussian模式] 處理 9552 個有血管的 patches，使用 batch_size=112
# Prediction done, transferring to CPU if needed
# [Done] spend 18.14 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 31.71 sec
# [Done Aneurysm AI Inference... ] spend 58 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76560791_20140924_MR_3030076660/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 50s 50s/step
# 1/1 [==============================] - 1s 818ms/step
# 1/1 [==============================] - 2s 2s/step
# [21] 76594030_20190321_MR_3080028202  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# old shape: (140, 560, 560), new_shape: [ 98 220 220], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7faa1d035630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 47432
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [96, 256, 256]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 98, 256, 256])
# data_vessel pad後的大小: torch.Size([1, 98, 256, 256])
# n_steps 2, image size is torch.Size([98, 256, 256]), tile_size [96, 256, 256], tile_step_size 0.25
# steps:
# [[0, 2], [0], [0]]
# [Gaussian模式] 處理 2 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 0.98 sec
# before
# predicted_array_or_file.shape: (2, 98, 220, 220)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 560, 560)
# current_spacing: [1.0, 1.0, 1.0]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 140, 560, 560)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.49999487
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.49999487
# [Done] spend 8.37 sec
# [Done Get brain mask... ] spend 25 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/Brain/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([64, 128, 128])
# old shape: (140, 560, 560), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7faa1d035630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 75621
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [64, 128, 128]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 1014, image size is torch.Size([140, 490, 490]), tile_size [64, 128, 128], tile_step_size 0.25
# steps:
# [[0, 15, 30, 46, 61, 76], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362]]
# [Gaussian模式] 處理 719 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 16.75 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 560, 560)
# current_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 140, 560, 560)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 23.21 sec
# [Done Vessel AI Inference... ] spend 52 sec
# [Done Get vessel post-process... ] spend 4 sec
# >>> predict_vessel_16labels ....................>>> (560, 560, 140)
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/Normalized_Image/DeepAneurysm_00001_0000.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/Vessel.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/Vessel_16.nii.gz
# [Done Get vessel 16labels... ] spend 70 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/Normalized_Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/Vessel/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([16, 32, 32])
# old shape: (140, 560, 560), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7faa1d035630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 10000
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [16, 32, 32]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 111392, image size is torch.Size([140, 490, 490]), tile_size [16, 32, 32], tile_step_size 0.25
# steps:
# [[0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96, 100, 104, 108, 112, 116, 120, 124], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458]]
# [Gaussian模式] 處理 8995 個有血管的 patches，使用 batch_size=112
# Prediction done, transferring to CPU if needed
# [Done] spend 18.79 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 560, 560)
# current_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 140, 560, 560)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 25.19 sec
# [Done Aneurysm AI Inference... ] spend 50 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 50s 50s/step
# 1/1 [==============================] - 1s 628ms/step
# 1/1 [==============================] - 2s 2s/step
# Chris Rorden's dcm2niiX version v1.0.20250505  GCC10.2.1 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# 1 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# DICOM images may be missing, expected 140 spatial locations per volume, but found 60 slices.
# Warning: Unable to distinguish Philips fieldmaps: phase difference, two phase/magnitude, direct fieldmapping.Philips Scaling Values RS:RI:SS = 9.02784:0:0.000971311 (see PMC3998685)
# Convert 60 DICOM as /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Image_reslice/MIP_Pitch (560x560x60x1)
# Conversion required 1.558873 seconds (1.558052 for core code).
# Chris Rorden's dcm2niiX version v1.0.20250505  GCC10.2.1 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# 1 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# DICOM images may be missing, expected 140 spatial locations per volume, but found 60 slices.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Interslice distance varies in this volume (incompatible with NIfTI format).
# Warning: Unable to distinguish Philips fieldmaps: phase difference, two phase/magnitude, direct fieldmapping.Philips Scaling Values RS:RI:SS = 9.02784:0:0.000971311 (see PMC3998685)
# Convert 60 DICOM as /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Image_reslice/MIP_Yaw (560x560x60x1)
# Warning: Unable to rotate 3D volume: slices not equidistant: 0.699999 != 1.4
# Only able to make equidistant slices from 8,16,24-bit integer or 32-bit float image data.76594030_20190321_MR_3080028202  Start...
# Running stage 1: Aneurysm inference!!!
# [Done stage 1: Aneurysm AI Inference... ] spend 217 sec
# [Done SynthSEG AI Inference... ] spend 85 sec
# reslice OK!!!
# [Done reslice... ] spend 29 sec
# [Done decompress_JEPG... ] spend 18 sec
# np.max(pred): 4 <class 'numpy.int16'>
# 從 Image Position 計算的 slice spacing: 0.7000 mm
# MIP 序列將使用統一的 slice_thickness: 0.7000 mm
# img.shape: (560, 560, 249) translated_pred: torch.Size([246, 560, 560])
# [MIP 數值驗證] MIP_Pitch MIP_images dtype=int32, min=0, max=329830
# Transfer syntax: 1.2.840.10008.1.2.1
# Image shape: (560, 560) dtype: uint16
# [MIP 數值驗證] MIP_Yaw MIP_images dtype=int32, min=0, max=329830
# Transfer syntax: 1.2.840.10008.1.2.1
# Image shape: (560, 560) dtype: uint16
# [Done create_MIP_pred... ] spend 89 sec
# Start: make_aneurysm_vessel_location_16labels_pred()
# Done: make_aneurysm_vessel_location_16labels_pred()
# Start: calculate_aneurysm_long_axis_make_pred()
# Done: calculate_aneurysm_long_axis_make_pred()
# Start: make_table_row_patient_pred()
# [0] 76594030_3080028202 Start...
# Done: make_table_row_patient_pred()
# Start: make_table_add_location()
# [0] 76594030_20190321_MR_3080028202 Start...
# Done: make_table_add_location()
# [Done calculate_aneurysm_long_axis... ] spend 6 sec
# Processing complete!an/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Dicom/Dicom-Seg/MIP_Yaw_A4.dcmcm
# [Done make_pred_json... ] spend 18 sec
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Dicom_zip/MRA_BRAIN 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Dicom_zip/MRA_BRAIN.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Dicom_zip/MIP_Pitch 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Dicom_zip/MIP_Pitch.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Dicom_zip/MIP_Yaw 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Dicom_zip/MIP_Yaw.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Dicom_zip/Dicom-Seg 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/Dicom_zip/Dicom-Seg.zip
# 200
#
# 200
#
# 200
#
# 200
#
# OK!!!
# [Done start_upload_dicom... ] spend 69 sec
# [Done All Pipeline!!! ] spend 372 sec
# [FollowUp] Skip: input_json is empty.
# [Upload] original json failed: /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76594030_20190321_MR_3080028202/nnUNet/JSON/76594030_20190321_MR_3080028202_platform_json.json err=[Errno 111] Connection refused
# end!!!
# [22] 76620764_20111011_MR_3000077828  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76620764_20111011_MR_3000077828/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76620764_20111011_MR_3000077828/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76620764_20111011_MR_3000077828/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# old shape: (140, 1024, 1024), new_shape: [ 98 220 220], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fee25c2d630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 47432
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [96, 256, 256]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 98, 256, 256])
# data_vessel pad後的大小: torch.Size([1, 98, 256, 256])
# n_steps 2, image size is torch.Size([98, 256, 256]), tile_size [96, 256, 256], tile_step_size 0.25
# steps:
# [[0, 2], [0], [0]]
# [Gaussian模式] 處理 2 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 0.92 sec
# before
# predicted_array_or_file.shape: (2, 98, 220, 220)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [1.0, 1.0, 1.0]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.4999858
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.4999858
# [Done] spend 34.76 sec
# [Done Get brain mask... ] spend 60 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76620764_20111011_MR_3000077828/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76620764_20111011_MR_3000077828/Brain/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([64, 128, 128])
# old shape: (140, 1024, 1024), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fee25c2d630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 89594
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [64, 128, 128]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 1014, image size is torch.Size([140, 490, 490]), tile_size [64, 128, 128], tile_step_size 0.25
# steps:
# [[0, 15, 30, 46, 61, 76], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362]]
# [Gaussian模式] 處理 854 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 19.76 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 34.52 sec
# [Done Vessel AI Inference... ] spend 60 sec
# [Done Get vessel post-process... ] spend 18 sec
# >>> predict_vessel_16labels .....................>>> (1024, 1024, 140)
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76620764_20111011_MR_3000077828/Normalized_Image/DeepAneurysm_00001_0000.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76620764_20111011_MR_3000077828/Vessel.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76620764_20111011_MR_3000077828/Vessel_16.nii.gz
# [Done Get vessel 16labels... ] spend 246 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76620764_20111011_MR_3000077828/Normalized_Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76620764_20111011_MR_3000077828/Vessel/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([16, 32, 32])
# old shape: (140, 1024, 1024), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7fee25c2d630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 10000
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [16, 32, 32]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 111392, image size is torch.Size([140, 490, 490]), tile_size [16, 32, 32], tile_step_size 0.25
# steps:
# [[0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96, 100, 104, 108, 112, 116, 120, 124], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458]]
# [Gaussian模式] 處理 8875 個有血管的 patches，使用 batch_size=112
# Prediction done, transferring to CPU if needed
# [Done] spend 18.06 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 1024, 1024)
# current_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 31.33 sec
# [Done Aneurysm AI Inference... ] spend 59 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76620764_20111011_MR_3000077828/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 50s 50s/step
# 1/1 [==============================] - 1s 742ms/step
# 1/1 [==============================] - 1s 1s/step
# [23] 76934390_20150904_MR_3040077477  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76934390_20150904_MR_3040077477/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76934390_20150904_MR_3040077477/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76934390_20150904_MR_3040077477/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# old shape: (150, 1024, 1024), new_shape: [105 220 220], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f67d71b5630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 50820
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [96, 256, 256]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 105, 256, 256])
# data_vessel pad後的大小: torch.Size([1, 105, 256, 256])
# n_steps 2, image size is torch.Size([105, 256, 256]), tile_size [96, 256, 256], tile_step_size 0.25
# steps:
# [[0, 9], [0], [0]]
# [Gaussian模式] 處理 2 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 0.91 sec
# before
# predicted_array_or_file.shape: (2, 105, 220, 220)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5
# properties_dict[shape_after_cropping_and_before_resampling]: (150, 1024, 1024)
# current_spacing: [1.0, 1.0, 1.0]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 150, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.4999988
# revert cropping
# probs_reverted_cropping.shape: (2, 150, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.4999988
# [Done] spend 34.54 sec
# [Done Get brain mask... ] spend 60 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76934390_20150904_MR_3040077477/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76934390_20150904_MR_3040077477/Brain/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([64, 128, 128])
# old shape: (150, 1024, 1024), new_shape: [150 490 490], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f67d71b5630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 85341
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [64, 128, 128]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 150, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 150, 490, 490])
# n_steps 1183, image size is torch.Size([150, 490, 490]), tile_size [64, 128, 128], tile_step_size 0.25
# steps:
# [[0, 14, 29, 43, 57, 72, 86], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362]]
# [Gaussian模式] 處理 974 個有血管的 patches，使�� batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 22.08 sec
# before
# predicted_array_or_file.shape: (2, 150, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (150, 1024, 1024)
# current_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 150, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 150, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 38.32 sec
# [Done Vessel AI Inference... ] spend 65 sec
# [Done Get vessel post-process... ] spend 17 sec
# >>> predict_vessel_16labels ...................>>> (1024, 1024, 150)
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76934390_20150904_MR_3040077477/Normalized_Image/DeepAneurysm_00001_0000.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76934390_20150904_MR_3040077477/Vessel.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76934390_20150904_MR_3040077477/Vessel_16.nii.gz
# [Done Get vessel 16labels... ] spend 238 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76934390_20150904_MR_3040077477/Normalized_Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76934390_20150904_MR_3040077477/Vessel/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([16, 32, 32])
# old shape: (150, 1024, 1024), new_shape: [150 490 490], old_spacing: [0.699999988079071, 0.21484375, 0.21484375], new_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7f67d71b5630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 10000
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [16, 32, 32]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 150, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 150, 490, 490])
# n_steps 121835, image size is torch.Size([150, 490, 490]), tile_size [16, 32, 32], tile_step_size 0.25
# steps:
# [[0, 4, 8, 12, 16, 20, 24, 28, 32, 35, 39, 43, 47, 51, 55, 59, 63, 67, 71, 75, 79, 83, 87, 91, 95, 99, 102, 106, 110, 114, 118, 122, 126, 130, 134], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458]]
# [Gaussian模式] 處理 6516 個有血管的 patches，使用 batch_size=112
# Prediction done, transferring to CPU if needed
# [Done] spend 19.26 sec
# before
# predicted_array_or_file.shape: (2, 150, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (150, 1024, 1024)
# current_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.21484375, 0.21484375]
# after
# predicted_array_or_file.shape: (2, 150, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 150, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 34.36 sec
# [Done Aneurysm AI Inference... ] spend 64 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76934390_20150904_MR_3040077477/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 50s 50s/step
# 1/1 [==============================] - 1s 812ms/step
# 1/1 [==============================] - 2s 2s/step
# [24] 76950216_20140625_MR_3030051645  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76950216_20140625_MR_3030051645/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76950216_20140625_MR_3030051645/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76950216_20140625_MR_3030051645/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/76950216_20140625_MR_3030051645/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 50s 50s/step
# 1/1 [==============================] - 1s 695ms/step
# 1/1 [==============================] - 2s 2s/step
# 76950216_20140625_MR_3030051645  Start...
# Running stage 1: Aneurysm inference!!!
# [Done stage 1: Aneurysm AI Inference... ] spend 49 sec
# [Done SynthSEG AI Inference... ] spend 93 sec
# end!!!
# [25] 77053740_20181130_MR_3070117003  Start...
# ...
# after
# predicted_array_or_file.shape: (2, 140, 1024, 1024)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 1024, 1024)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 32.94 sec
# [Done Aneurysm AI Inference... ] spend 79 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77431713_20151123_MR_3040102191/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 52s 52s/step
# 1/1 [==============================] - 1s 992ms/step
# 1/1 [==============================] - 2s 2s/step
# [29] 77512060_20180606_MR_3070055773  Start...
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/Ones/DeepAneurysm_00001_0000.nii.gz
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/Ones/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([96, 256, 256])
# old shape: (140, 560, 560), new_shape: [ 98 220 220], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [1.0, 1.0, 1.0], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7eff50e41630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 47432
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [96, 256, 256]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 98, 256, 256])
# data_vessel pad後的大小: torch.Size([1, 98, 256, 256])
# n_steps 2, image size is torch.Size([98, 256, 256]), tile_size [96, 256, 256], tile_step_size 0.25
# steps:
# [[0, 2], [0], [0]]
# [Gaussian模式] 處理 2 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 1.29 sec
# before
# predicted_array_or_file.shape: (2, 98, 220, 220)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.5
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 560, 560)
# current_spacing: [1.0, 1.0, 1.0]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 140, 560, 560)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.49999893
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.49999893
# [Done] spend 7.23 sec
# [Done Get brain mask... ] spend 21 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/Brain/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([64, 128, 128])
# old shape: (140, 560, 560), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7eff50e41630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 63811
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [64, 128, 128]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 1014, image size is torch.Size([140, 490, 490]), tile_size [64, 128, 128], tile_step_size 0.25
# steps:
# [[0, 15, 30, 46, 61, 76], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362], [0, 30, 60, 90, 121, 151, 181, 211, 241, 272, 302, 332, 362]]
# [Gaussian模式] 處理 738 個有血管的 patches，使用 batch_size=16
# Prediction done, transferring to CPU if needed
# [Done] spend 17.58 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 560, 560)
# current_spacing: [0.699999988079071, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 140, 560, 560)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 23.99 sec
# [Done Vessel AI Inference... ] spend 52 sec
# [Done Get vessel post-process... ] spend 4 sec
# >>> predict_vessel_16labels ..................>>> (560, 560, 140)
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/Normalized_Image/DeepAneurysm_00001_0000.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/Vessel.nii.gz
# [save] ---> /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/Vessel_16.nii.gz
# [Done Get vessel 16labels... ] spend 65 sec
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 總共有幾個網路parameters(同時拿幾個網路預測): 1
# There are 1 cases in the source folder
# I am process 0 out of 1 (max process ID is 0, we start counting with 0!)
# There are 1 cases that I would like to predict
# list_of_lists_or_source_folder example: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/Normalized_Image/DeepAneurysm_00001_0000.nii.gz']
# Mask_list_of_lists_or_Mask_folder: ['/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/Vessel/DeepAneurysm_00001_0000.nii.gz']
# overwrite was set to False, so I am only working on cases that haven't been predicted yet. That's 1 cases.
# inference_gaussian.shape: torch.Size([16, 32, 32])
# old shape: (140, 560, 560), new_shape: [140 490 490], old_spacing: [0.699999988079071, 0.3928571343421936, 0.3928571343421936], new_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814], fn_data: functools.partial(<function resample_data_or_seg_to_shape at 0x7eff50e41630>, is_seg=False, order=3, order_z=0, force_separate_z=None)
# 1 10000
#
# Predicting DeepAneurysm_00001:
# perform_everything_on_gpu: True
# configuration_manager.patch_size: [16, 32, 32]
# step_size: 0.25
# mirror_axes: None
# step_size: 0.25
# mirror_axes: None
# data pad後的大小: torch.Size([1, 140, 490, 490])
# data_vessel pad後的大小: torch.Size([1, 140, 490, 490])
# n_steps 111392, image size is torch.Size([140, 490, 490]), tile_size [16, 32, 32], tile_step_size 0.25
# steps:
# [[0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96, 100, 104, 108, 112, 116, 120, 124], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458], [0, 8, 16, 24, 32, 39, 47, 55, 63, 71, 79, 87, 95, 103, 111, 118, 126, 134, 142, 150, 158, 166, 174, 182, 190, 197, 205, 213, 221, 229, 237, 245, 253, 261, 268, 276, 284, 292, 300, 308, 316, 324, 332, 340, 347, 355, 363, 371, 379, 387, 395, 403, 411, 419, 426, 434, 442, 450, 458]]
# [Gaussian模式] 處理 7462 個有血管的 patches，使用 batch_size=112
# Prediction done, transferring to CPU if needed
# [Done] spend 17.26 sec
# before
# predicted_array_or_file.shape: (2, 140, 490, 490)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# properties_dict[shape_after_cropping_and_before_resampling]: (140, 560, 560)
# current_spacing: [0.6999997496604919, 0.44920000433921814, 0.44920000433921814]
# properties_dict[spacing]: [0.699999988079071, 0.3928571343421936, 0.3928571343421936]
# after
# predicted_array_or_file.shape: (2, 140, 560, 560)
# np.max(predicted_array_or_file): 1.0
# np.median(predicted_array_or_file): 0.0
# revert cropping
# probs_reverted_cropping.shape: (2, 140, 560, 560)
# np.max(probs_reverted_cropping): 1.0
# np.median(probs_reverted_cropping): 0.0
# [Done] spend 23.49 sec
# [Done Aneurysm AI Inference... ] spend 48 sec
# Using Pytorch.
# Namespace(input='/data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Image_nii', input_name='MRA_BRAIN.nii.gz', output=None, template=None, template_name=None, all=False, wm_file=True, cmb=False, cmb_file='CMB', dwi=False, dwi_file='DWI', wmh=False, wmh_file='WMH', depth_number=5)
# 1/1 [==============================] - 51s 51s/step
# 1/1 [==============================] - 1s 960ms/step
# 1/1 [==============================] - 2s 2s/step
# Chris Rorden's dcm2niiX version v1.0.20250505  GCC10.2.1 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# 1 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# DICOM images may be missing, expected 140 spatial locations per volume, but found 60 slices.
# Warning: Unable to distinguish Philips fieldmaps: phase difference, two phase/magnitude, direct fieldmapping.Philips Scaling Values RS:RI:SS = 7.07741:0:0.000970494 (see PMC3998685)
# Convert 60 DICOM as /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Image_reslice/MIP_Pitch (560x560x60x1)
# Conversion required 1.483169 seconds (1.480139 for core code).
# Chris Rorden's dcm2niiX version v1.0.20250505  GCC10.2.1 x86-64 (64-bit Linux)
# Found 61 DICOM file(s)
# 1 images have identical time, series, acquisition and instance values. DUPLICATES REMOVED.
# DICOM images may be missing, expected 140 spatial locations per volume, but found 60 slices.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Instance Number (0020,0013) order is not spatial.
# Warning: Interslice distance varies in this volume (incompatible with NIfTI format).
# Warning: Unable to distinguish Philips fieldmaps: phase difference, two phase/magnitude, direct fieldmapping.Philips Scaling Values RS:RI:SS = 7.07741:0:0.000970494 (see PMC3998685)
# Convert 60 DICOM as /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Image_reslice/MIP_Yaw (560x560x60x1)
# Warning: Unable to rotate 3D volume: slices not equidistant: 0.700002 != 1.40001
# Only able to make equidistant slices from 8,16,24-bit integer or 32-bit float image data.77512060_20180606_MR_3070055773  Start...
# Running stage 1: Aneurysm inference!!!
# [Done stage 1: Aneurysm AI Inference... ] spend 204 sec
# [Done SynthSEG AI Inference... ] spend 85 sec
# reslice OK!!!
# [Done reslice... ] spend 21 sec
# [Done decompress_JEPG... ] spend 18 sec
# np.max(pred): 4 <class 'numpy.int16'>
# 從 Image Position 計算的 slice spacing: 0.7000 mm
# MIP 序列將使用統一的 slice_thickness: 0.7000 mm
# img.shape: (560, 560, 249) translated_pred: torch.Size([246, 560, 560])
# [MIP 數值驗證] MIP_Pitch MIP_images dtype=int32, min=0, max=384362
# Transfer syntax: 1.2.840.10008.1.2.1
# Image shape: (560, 560) dtype: uint16
# [MIP 數值驗證] MIP_Yaw MIP_images dtype=int32, min=0, max=384362
# Transfer syntax: 1.2.840.10008.1.2.1
# Image shape: (560, 560) dtype: uint16
# [Done create_MIP_pred... ] spend 96 sec
# Start: make_aneurysm_vessel_location_16labels_pred()
# Done: make_aneurysm_vessel_location_16labels_pred()
# Start: calculate_aneurysm_long_axis_make_pred()
# Done: calculate_aneurysm_long_axis_make_pred()
# Start: make_table_row_patient_pred()
# [0] 77512060_3070055773 Start...
# Done: make_table_row_patient_pred()
# Start: make_table_add_location()
# [0] 77512060_20180606_MR_3070055773 Start...
# Done: make_table_add_location()
# [Done calculate_aneurysm_long_axis... ] spend 6 sec
# Processing complete!an/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Dicom/Dicom-Seg/MIP_Yaw_A4.dcmcm
# [Done make_pred_json... ] spend 14 sec
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Dicom_zip/MRA_BRAIN 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Dicom_zip/MRA_BRAIN.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Dicom_zip/MIP_Pitch 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Dicom_zip/MIP_Pitch.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Dicom_zip/MIP_Yaw 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Dicom_zip/MIP_Yaw.zip
# /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Dicom_zip/Dicom-Seg 已壓縮成 /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/Dicom_zip/Dicom-Seg.zip
# 200
#
# 200
#
# 200
#
# 200
#
# OK!!!
# [Done start_upload_dicom... ] spend 61 sec
# [Done All Pipeline!!! ] spend 388 sec
# [FollowUp] Skip: input_json is empty.
# [Upload] original json failed: /data/chuan/Deep_Aneurysm/Result/Skull_fat_FalsePositive/TMMH/process/Deep_Aneurysm/77512060_20180606_MR_3070055773/nnUNet/JSON/77512060_20180606_MR_3070055773_platform_json.json err=[Errno 111] Connection refused
# end!!!
